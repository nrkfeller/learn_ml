# %%
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# # Skip Gram

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'of', 'originated', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(
        tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.071652
# Nearest to american: unguarded, tellers, premier, entertainers, abhidharma, drew, optimized, toynbee,
# Nearest to at: atom, solidify, leonards, bowman, qos, hoch, rebbe, clerihew,
# Nearest to states: fock, garfield, strangled, dna, plekhanov, yarns, feyerabend, guide,
# Nearest to most: berry, arte, hasty, makeshift, dots, ker, franks, eucharistic,
# Nearest to or: zia, enrique, amplifies, biomedical, catalan, euskara, baldr, whores,
# Nearest to has: remarkably, transgenic, proceedings, rebellions, ascetics, leinster, vassar, skeleton,
# Nearest to with: subshell, soloists, overcrowding, pacemaker, flores, rooney, ambulances, jabber,
# Nearest to see: convinces, reynolds, inconsistent, strawberries, discipleship, neuromuscular, negligence, piped,
# Nearest to world: intrigued, gol, ajaccio, displacing, himachal, vii, lasor, lamborghini,
# Nearest to so: canvas, satie, hala, perlite, mamluks, term, conception, theatrically,
# Nearest to and: spotter, drunken, positively, aircraft, correctness, omnivorous, contrapuntal, atp,
# Nearest to history: severed, concatenation, chalcolithic, hofmann, layering, restricts, pallium, triumphal,
# Nearest to than: immune, titles, mush, benign, sculptor, gov, abodes, remake,
# Nearest to three: ushered, xhtml, sayles, microfluidics, dd, knew, prizes, gout,
# Nearest to time: retake, sasson, ladin, alkaloid, hebron, lesbians, sch, islets,
# Nearest to in: emulated, cheetah, zebulun, meteorological, aussie, conversation, testify, hypnotized,
# Average loss at step 2000: 4.365873
# Average loss at step 4000: 3.865185
# Average loss at step 6000: 3.792886
# Average loss at step 8000: 3.692407
# Average loss at step 10000: 3.614944
# Nearest to american: ukrainian, entertainers, toynbee, counselors, abhidharma, exoplanets, schwarzenegger, distraught,
# Nearest to at: on, in, from, xxxiii, mls, hadn, rial, makes,
# Nearest to states: dna, retrieve, fock, dect, aleister, strangled, plains, illustrative,
# Nearest to most: makeshift, arte, synods, diet, toulouse, ker, kildare, piet,
# Nearest to or: and, condemning, charleroi, thomas, fem, poem, dares, sukarnoputri,
# Nearest to has: had, was, have, is, quarreled, became, proceedings, skeleton,
# Nearest to with: for, in, by, machado, homelessness, on, hissing, during,
# Nearest to see: convinces, asgard, inches, pandemic, flip, theobald, making, bioethics,
# Nearest to world: odes, gol, lamborghini, united, clarifies, displacing, parlour, lunatics,
# Nearest to so: theatrically, mamluks, conception, unidad, hala, swallowed, harpsichords, shamanic,
# Nearest to and: or, s, but, he, winger, mystique, herschel, gnomes,
# Nearest to history: hofmann, concatenation, kkinen, rote, severed, decoders, phillip, pizan,
# Nearest to than: mush, min, much, immune, titles, transition, wulf, protesting,
# Nearest to three: four, five, eight, six, seven, two, nine, zero,
# Nearest to time: en, retake, ladin, him, islets, sasson, living, lesbians,
# Nearest to in: on, of, at, with, from, after, mainstays, for,
# Average loss at step 12000: 3.604920
# Average loss at step 14000: 3.573507
# Average loss at step 16000: 3.412776
# Average loss at step 18000: 3.466140
# Average loss at step 20000: 3.539200
# Nearest to american: british, counselors, english, mexican, entertainers, russian, ukrainian, paramagnetic,
# Nearest to at: in, on, with, from, xxxiii, and, rial, hadn,
# Nearest to states: fock, areas, dna, budgeted, silently, dect, exponents, indignation,
# Nearest to most: some, many, ker, forms, quarries, synods, admiration, kildare,
# Nearest to or: and, than, sukarnoputri, microscope, condemning, for, tei, mohawk,
# Nearest to has: had, have, is, was, quarreled, provides, spices, pcm,
# Nearest to with: at, in, and, by, hissing, between, for, crawford,
# Nearest to see: asgard, but, inches, convinces, bioethics, flip, pandemic, know,
# Nearest to world: thinner, gol, odes, parlour, lunatics, render, falcon, pathways,
# Nearest to so: bono, mamluks, unidad, conception, satie, theatrically, plantarum, direct,
# Nearest to and: or, but, from, dhekelia, at, in, with, which,
# Nearest to history: hofmann, concatenation, phillip, dozenal, swapping, kkinen, because, retract,
# Nearest to than: or, much, mush, cleve, hoff, immune, transition, wulf,
# Nearest to three: four, seven, six, five, two, eight, nine, zero,
# Nearest to time: bathroom, nearly, manco, en, living, bcl, praising, islets,
# Nearest to in: at, on, during, with, from, and, around, of,
# Average loss at step 22000: 3.505316
# Average loss at step 24000: 3.492087
# Average loss at step 26000: 3.486495
# Average loss at step 28000: 3.482383
# Average loss at step 30000: 3.503380
# Nearest to american: british, english, russian, goalscorer, philly, counselors, italian, junta,
# Nearest to at: in, xxxiii, on, during, beads, after, anisotropy, decorum,
# Nearest to states: nations, fock, areas, silently, enjoy, onetime, countries, blade,
# Nearest to most: more, many, some, among, makeshift, origins, less, declare,
# Nearest to or: and, cardinals, than, libels, redistribution, atrocity, scaling, hawkwind,
# Nearest to has: had, have, is, was, provides, longbow, quarreled, rumford,
# Nearest to with: between, under, subshell, during, in, as, for, when,
# Nearest to see: but, external, inches, replied, asgard, tiberian, gulliver, birka,
# Nearest to world: parlour, thinner, falcon, gol, odes, lunatics, conquest, walton,
# Nearest to so: bono, mamluks, conception, theatrically, direct, orbiter, deciphering, swallowed,
# Nearest to and: or, but, in, fragrant, kriegsmarine, of, declaring, taking,
# Nearest to history: dozenal, retract, swapping, shipwrecks, kkinen, bicarbonate, pizan, hernia,
# Nearest to than: much, for, subjunctive, or, protesting, hoff, gerry, insolvency,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to time: nearly, islets, year, thirsty, docked, reviled, period, point,
# Nearest to in: during, on, at, of, from, throughout, between, under,
# Average loss at step 32000: 3.499223
# Average loss at step 34000: 3.493581
# Average loss at step 36000: 3.457724
# Average loss at step 38000: 3.297625
# Average loss at step 40000: 3.428009
# Nearest to american: british, english, australian, philly, entertainers, goalscorer, russian, german,
# Nearest to at: on, during, in, decorum, galtieri, fringes, nearby, vertically,
# Nearest to states: countries, nations, areas, fock, kingdom, revocation, silently, aims,
# Nearest to most: more, many, among, less, ker, some, sanctification, declare,
# Nearest to or: and, than, mohawk, libels, coincide, condemning, congresses, org,
# Nearest to has: had, have, was, provides, is, baptized, having, since,
# Nearest to with: by, dtv, between, dg, in, mysterious, when, forum,
# Nearest to see: but, lobby, known, external, tran, include, renewed, gulliver,
# Nearest to world: lunatics, thinner, falcon, championship, civil, cryptanalysis, dalmatian, kosovo,
# Nearest to so: bono, mamluks, too, willard, theatrically, conception, deciphering, adoptionism,
# Nearest to and: or, but, in, giuseppe, ypres, whyte, thien, afterthought,
# Nearest to history: swapping, concatenation, dozenal, list, overview, product, delaney, retract,
# Nearest to than: or, much, subjunctive, gerry, titles, mindful, compressed, carcasses,
# Nearest to three: six, four, seven, five, two, eight, nine, zero,
# Nearest to time: year, place, day, reviled, way, assemble, period, docked,
# Nearest to in: from, and, for, of, on, ludo, solitaire, grabs,
# Average loss at step 42000: 3.433853
# Average loss at step 44000: 3.452335
# Average loss at step 46000: 3.450524
# Average loss at step 48000: 3.351105
# Average loss at step 50000: 3.390160
# Nearest to american: british, english, australian, goalscorer, international, russian, italian, entertainers,
# Nearest to at: during, in, on, instinctive, ignosticism, graphs, lapses, from,
# Nearest to states: nations, kingdom, countries, revocation, fock, kokomo, tribesmen, buber,
# Nearest to most: more, many, some, less, among, origins, admiration, preprint,
# Nearest to or: and, than, mayfield, dianne, tools, org, like, condemning,
# Nearest to has: had, have, was, is, having, provides, idealised, since,
# Nearest to with: between, by, dg, when, delaunay, subshell, without, at,
# Nearest to see: external, include, greenstone, adagio, lobby, gangrene, gulliver, inches,
# Nearest to world: thinner, sacrament, lunatics, falcon, championship, walton, pulmonic, contained,
# Nearest to so: if, heim, orbiter, too, canvas, bono, illyria, cabinda,
# Nearest to and: or, but, including, than, like, however, s, repeatable,
# Nearest to history: list, dozenal, concatenation, delaney, because, parlour, clumsy, retract,
# Nearest to than: or, and, much, carcasses, subjunctive, titles, mindful, dich,
# Nearest to three: four, seven, six, eight, two, five, nine, zero,
# Nearest to time: place, way, day, year, point, period, nearly, amylase,
# Nearest to in: during, of, on, from, since, throughout, between, at,
# Average loss at step 52000: 3.438360
# Average loss at step 54000: 3.428712
# Average loss at step 56000: 3.436807
# Average loss at step 58000: 3.394989
# Average loss at step 60000: 3.394783
# Nearest to american: british, australian, goalscorer, english, international, philly, russian, german,
# Nearest to at: in, during, xxxiii, josephus, rial, mls, hadn, nearby,
# Nearest to states: nations, kingdom, countries, state, purposes, areas, fock, under,
# Nearest to most: more, many, some, origins, beginning, atanasoff, less, use,
# Nearest to or: and, than, like, zones, org, mayfield, for, including,
# Nearest to has: had, have, was, is, provides, quarreled, idealised, having,
# Nearest to with: between, by, homelessness, when, collating, among, dg, lakeshore,
# Nearest to see: external, include, but, lobby, adagio, list, includes, greenstone,
# Nearest to world: conquest, falcon, thinner, civil, pathways, sacrament, lunatics, dalmatian,
# Nearest to so: too, if, darling, bono, cabinda, kohlberg, adoptionism, bournemouth,
# Nearest to and: or, but, than, longbowmen, including, like, although, faraday,
# Nearest to history: list, mandatory, parlour, clumsy, retract, info, electrolytes, overview,
# Nearest to than: or, much, and, subjunctive, mindful, carcasses, inoffensive, dich,
# Nearest to three: five, four, seven, six, eight, two, nine, one,
# Nearest to time: place, way, point, year, period, worry, slept, amylase,
# Nearest to in: during, within, between, of, on, at, including, since,
# Average loss at step 62000: 3.243712
# Average loss at step 64000: 3.260896
# Average loss at step 66000: 3.401079
# Average loss at step 68000: 3.397506
# Average loss at step 70000: 3.358946
# Nearest to american: british, international, goalscorer, australian, english, philly, entertainers, lexus,
# Nearest to at: during, auditor, on, in, lapses, cti, mls, publically,
# Nearest to states: nations, kingdom, state, countries, areas, tribesmen, onetime, fock,
# Nearest to most: more, many, less, some, origins, among, admiration, postmodern,
# Nearest to or: and, than, while, but, gestation, override, like, licenses,
# Nearest to has: had, have, was, is, provides, since, idealised, having,
# Nearest to with: between, collating, hissing, mysterious, informal, without, when, dod,
# Nearest to see: include, external, lobby, adagio, list, but, and, dharmas,
# Nearest to world: lunatics, falcon, pathways, thinner, samos, planetarium, kosovo, u,
# Nearest to so: too, heim, white, if, darling, influencing, dunlop, willard,
# Nearest to and: or, but, like, while, than, hawkwind, including, stag,
# Nearest to history: list, duration, version, electrolytes, retract, overview, pizan, abc,
# Nearest to than: or, subjunctive, much, but, mindful, and, inoffensive, dich,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to time: place, period, amylase, way, year, lesbians, eck, point,
# Nearest to in: within, during, throughout, on, for, until, through, between,
# Average loss at step 72000: 3.377348
# Average loss at step 74000: 3.347487
# Average loss at step 76000: 3.314245
# Average loss at step 78000: 3.356060
# Average loss at step 80000: 3.379282
# Nearest to american: british, international, australian, goalscorer, english, canadian, mexican, entertainers,
# Nearest to at: during, on, before, in, around, after, towards, beads,
# Nearest to states: nations, kingdom, countries, state, fock, tribesmen, kokomo, borne,
# Nearest to most: many, some, more, less, particularly, manifested, among, pew,
# Nearest to or: and, than, while, mayfield, dianne, ssris, utilization, silky,
# Nearest to has: had, have, was, is, since, having, provides, multiparty,
# Nearest to with: between, when, during, subshell, in, creditor, hissing, including,
# Nearest to see: include, external, but, fright, adagio, includes, dharmas, jakob,
# Nearest to world: lunatics, thinner, falcon, samos, u, pulmonic, odes, peacetime,
# Nearest to so: too, heim, darling, micronation, kohlberg, bono, if, orbiter,
# Nearest to and: or, including, stag, but, than, rik, although, declaring,
# Nearest to history: list, duration, misled, electrolytes, niall, erica, uns, laughs,
# Nearest to than: much, or, and, subjunctive, dich, insolvency, while, mindful,
# Nearest to three: six, four, seven, five, eight, two, nine, one,
# Nearest to time: place, year, period, assemble, depletion, century, rsha, round,
# Nearest to in: during, within, on, until, between, throughout, since, primordial,
# Average loss at step 82000: 3.405595
# Average loss at step 84000: 3.412717
# Average loss at step 86000: 3.390208
# Average loss at step 88000: 3.352493
# Average loss at step 90000: 3.362769
# Nearest to american: british, australian, international, indian, italian, goalscorer, english, canadian,
# Nearest to at: during, on, in, towards, near, schuster, graphs, under,
# Nearest to states: nations, kingdom, countries, state, kokomo, tribesmen, us, areas,
# Nearest to most: many, more, some, less, origins, particularly, manifested, among,
# Nearest to or: and, including, while, than, ssris, dianne, reopened, but,
# Nearest to has: had, have, is, was, having, since, provides, idealised,
# Nearest to with: between, subshell, in, when, without, by, hissing, during,
# Nearest to see: include, external, includes, purine, list, jakob, beaulieu, references,
# Nearest to world: lunatics, thinner, civil, heligoland, planetarium, mutinied, morrow, zoom,
# Nearest to so: too, white, heim, kohlberg, orbiter, if, micronation, bono,
# Nearest to and: or, but, while, including, pieter, although, stag, absorbance,
# Nearest to history: list, duration, misled, marking, period, niall, description, parlour,
# Nearest to than: much, subjunctive, or, dich, mindful, gerry, inoffensive, fangio,
# Nearest to three: four, two, five, seven, eight, six, nine, one,
# Nearest to time: period, year, amylase, depletion, curtailed, assemble, place, eck,
# Nearest to in: during, within, under, at, throughout, of, between, leena,
# Average loss at step 92000: 3.399521
# Average loss at step 94000: 3.256161
# Average loss at step 96000: 3.358037
# Average loss at step 98000: 3.245761
# Average loss at step 100000: 3.353741
# Nearest to american: british, italian, australian, canadian, international, indian, goalscorer, russian,
# Nearest to at: on, during, near, in, schuster, krush, lapses, after,
# Nearest to states: nations, kingdom, countries, us, kokomo, state, forrest, areas,
# Nearest to most: more, less, particularly, many, some, iterated, pew, origins,
# Nearest to or: and, than, reopened, ssris, lang, alternating, while, mayfield,
# Nearest to has: had, have, is, was, since, provides, having, idealised,
# Nearest to with: between, hissing, of, in, isaias, at, when, lionhead,
# Nearest to see: external, includes, include, refers, list, manipulates, links, dharmas,
# Nearest to world: u, country, civil, thinner, championship, indications, dedicate, planetarium,
# Nearest to so: too, thus, orbiter, bono, kohlberg, theosophy, heim, rdoba,
# Nearest to and: or, but, while, mabuse, of, although, however, who,
# Nearest to history: description, list, review, misled, duration, marking, parlour, overview,
# Nearest to than: or, much, subjunctive, inoffensive, tantric, dich, mindful, archipelagoes,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to time: year, assemble, depletion, place, eck, period, ty, amylase,
# Nearest to in: during, within, throughout, until, on, from, through, into,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Continuous Bag of Words
